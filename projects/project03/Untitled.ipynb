# %%
['CLIMATE.REGION', 'ANOMALY.LEVEL']
0.14
['CLIMATE.REGION', 'CLIMATE.CATEGORY']
0.105
['CLIMATE.REGION', 'OUTAGE.START.DATE']
0.125
['CLIMATE.REGION', 'OUTAGE.START.TIME']
0.1
['CLIMATE.REGION', 'OUTAGE.RESTORATION.DATE']
0.0
['CLIMATE.REGION', 'OUTAGE.RESTORATION.TIME']
0.0
['CLIMATE.REGION', 'CAUSE.CATEGORY']
0.0
['CLIMATE.REGION', 'CAUSE.CATEGORY.DETAIL']
0.0
['CLIMATE.REGION', 'HURRICANE.NAMES']
0.0
['CLIMATE.REGION', 'OUTAGE.DURATION']
0.0
['CLIMATE.REGION', 'DEMAND.LOSS.MW']
0.0
['CLIMATE.REGION', 'CUSTOMERS.AFFECTED']
0.0
['CLIMATE.REGION', 'RES.PRICE']
0.0
['CLIMATE.REGION', 'COM.PRICE']
0.0
['CLIMATE.REGION', 'IND.PRICE']
0.0
['CLIMATE.REGION', 'TOTAL.PRICE']
0.0
['CLIMATE.REGION', 'RES.SALES']
0.0
['CLIMATE.REGION', 'COM.SALES']
0.0
['CLIMATE.REGION', 'IND.SALES']
0.0
['CLIMATE.REGION', 'TOTAL.SALES']
0.0
['CLIMATE.REGION', 'RES.PERCEN']
0.0
['CLIMATE.REGION', 'COM.PERCEN']
0.0
['CLIMATE.REGION', 'IND.PERCEN']
0.0
['CLIMATE.REGION', 'RES.CUSTOMERS']
0.0
['CLIMATE.REGION', 'COM.CUSTOMERS']
0.0
['CLIMATE.REGION', 'IND.CUSTOMERS']
0.0
['CLIMATE.REGION', 'TOTAL.CUSTOMERS']
0.0
['CLIMATE.REGION', 'RES.CUST.PCT']
0.0
['CLIMATE.REGION', 'COM.CUST.PCT']
0.0
['CLIMATE.REGION', 'IND.CUST.PCT']
0.0
['CLIMATE.REGION', 'PC.REALGSP.STATE']
0.0
['CLIMATE.REGION', 'PC.REALGSP.USA']
0.0
['CLIMATE.REGION', 'PC.REALGSP.REL']
0.0
['CLIMATE.REGION', 'PC.REALGSP.CHANGE']
0.0
['CLIMATE.REGION', 'UTIL.REALGSP']
0.0
['CLIMATE.REGION', 'TOTAL.REALGSP']
0.0
['CLIMATE.REGION', 'UTIL.CONTRI']
0.0
['CLIMATE.REGION', 'PI.UTIL.OFUSA']
0.0
['CLIMATE.REGION', 'POPULATION']
0.0
['CLIMATE.REGION', 'POPPCT_URBAN']
0.0
['CLIMATE.REGION', 'POPPCT_UC']
0.0
['CLIMATE.REGION', 'POPDEN_URBAN']
0.0
['CLIMATE.REGION', 'POPDEN_UC']
0.02
['CLIMATE.REGION', 'POPDEN_RURAL']
0.035
['CLIMATE.REGION', 'AREAPCT_URBAN']
0.0
['CLIMATE.REGION', 'AREAPCT_UC']
0.0
['CLIMATE.REGION', 'PCT_LAND']
0.0
['CLIMATE.REGION', 'PCT_WATER_TOT']
0.0
['CLIMATE.REGION', 'PCT_WATER_INLAND']
0.0
['CLIMATE.REGION', 'OUTAGE.START']
0.09
['ANOMALY.LEVEL', 'CLIMATE.REGION']
1.0
['ANOMALY.LEVEL', 'CLIMATE.CATEGORY']
1.0
['ANOMALY.LEVEL', 'OUTAGE.START.DATE']
0.99
['ANOMALY.LEVEL', 'OUTAGE.START.TIME']
0.995
['ANOMALY.LEVEL', 'OUTAGE.RESTORATION.DATE']
0.0
['ANOMALY.LEVEL', 'OUTAGE.RESTORATION.TIME']
0.0
['ANOMALY.LEVEL', 'CAUSE.CATEGORY']
0.0
['ANOMALY.LEVEL', 'CAUSE.CATEGORY.DETAIL']
0.0
['ANOMALY.LEVEL', 'HURRICANE.NAMES']
0.0
['ANOMALY.LEVEL', 'OUTAGE.DURATION']
0.0
['ANOMALY.LEVEL', 'DEMAND.LOSS.MW']
0.0
['ANOMALY.LEVEL', 'CUSTOMERS.AFFECTED']
0.0
['ANOMALY.LEVEL', 'RES.PRICE']
0.16
['ANOMALY.LEVEL', 'COM.PRICE']
0.22
['ANOMALY.LEVEL', 'IND.PRICE']
0.22
['ANOMALY.LEVEL', 'TOTAL.PRICE']
0.24
['ANOMALY.LEVEL', 'RES.SALES']
0.275
['ANOMALY.LEVEL', 'COM.SALES']
0.24
['ANOMALY.LEVEL', 'IND.SALES']
0.24
['ANOMALY.LEVEL', 'TOTAL.SALES']
0.26
['ANOMALY.LEVEL', 'RES.PERCEN']
0.22
['ANOMALY.LEVEL', 'COM.PERCEN']
0.255
['ANOMALY.LEVEL', 'IND.PERCEN']
0.25
['ANOMALY.LEVEL', 'RES.CUSTOMERS']
0.0
['ANOMALY.LEVEL', 'COM.CUSTOMERS']
0.0
['ANOMALY.LEVEL', 'IND.CUSTOMERS']
0.0
['ANOMALY.LEVEL', 'TOTAL.CUSTOMERS']
0.0
['ANOMALY.LEVEL', 'RES.CUST.PCT']
0.0
['ANOMALY.LEVEL', 'COM.CUST.PCT']
0.0
['ANOMALY.LEVEL', 'IND.CUST.PCT']
0.0
['ANOMALY.LEVEL', 'PC.REALGSP.STATE']
0.0
['ANOMALY.LEVEL', 'PC.REALGSP.USA']
0.0
['ANOMALY.LEVEL', 'PC.REALGSP.REL']
0.0
['ANOMALY.LEVEL', 'PC.REALGSP.CHANGE']
0.0
['ANOMALY.LEVEL', 'UTIL.REALGSP']
0.0
['ANOMALY.LEVEL', 'TOTAL.REALGSP']
0.0
['ANOMALY.LEVEL', 'UTIL.CONTRI']
0.0
['ANOMALY.LEVEL', 'PI.UTIL.OFUSA']
0.0
['ANOMALY.LEVEL', 'POPULATION']
0.0
['ANOMALY.LEVEL', 'POPPCT_URBAN']
0.0
['ANOMALY.LEVEL', 'POPPCT_UC']
0.0
['ANOMALY.LEVEL', 'POPDEN_URBAN']
0.0
['ANOMALY.LEVEL', 'POPDEN_UC']
0.97
['ANOMALY.LEVEL', 'POPDEN_RURAL']
0.95
['ANOMALY.LEVEL', 'AREAPCT_URBAN']
0.0
['ANOMALY.LEVEL', 'AREAPCT_UC']
0.0
['ANOMALY.LEVEL', 'PCT_LAND']
0.0
['ANOMALY.LEVEL', 'PCT_WATER_TOT']
0.0
['ANOMALY.LEVEL', 'PCT_WATER_INLAND']
0.0
['ANOMALY.LEVEL', 'OUTAGE.START']
1.0
['CLIMATE.CATEGORY', 'CLIMATE.REGION']
0.015
['CLIMATE.CATEGORY', 'ANOMALY.LEVEL']
0.01
['CLIMATE.CATEGORY', 'OUTAGE.START.DATE']
0.0
['CLIMATE.CATEGORY', 'OUTAGE.START.TIME']
0.015
['CLIMATE.CATEGORY', 'OUTAGE.RESTORATION.DATE']
0.0
['CLIMATE.CATEGORY', 'OUTAGE.RESTORATION.TIME']
0.0
['CLIMATE.CATEGORY', 'CAUSE.CATEGORY']
0.0
['CLIMATE.CATEGORY', 'CAUSE.CATEGORY.DETAIL']
0.0
['CLIMATE.CATEGORY', 'HURRICANE.NAMES']
0.0
['CLIMATE.CATEGORY', 'OUTAGE.DURATION']
0.0
['CLIMATE.CATEGORY', 'DEMAND.LOSS.MW']
0.0
['CLIMATE.CATEGORY', 'CUSTOMERS.AFFECTED']
0.0
['CLIMATE.CATEGORY', 'RES.PRICE']
0.0
['CLIMATE.CATEGORY', 'COM.PRICE']
0.0
['CLIMATE.CATEGORY', 'IND.PRICE']
0.0
['CLIMATE.CATEGORY', 'TOTAL.PRICE']
0.0
['CLIMATE.CATEGORY', 'RES.SALES']
0.0
['CLIMATE.CATEGORY', 'COM.SALES']
0.0
['CLIMATE.CATEGORY', 'IND.SALES']
0.0
['CLIMATE.CATEGORY', 'TOTAL.SALES']
0.0
['CLIMATE.CATEGORY', 'RES.PERCEN']
0.0
['CLIMATE.CATEGORY', 'COM.PERCEN']
0.0
['CLIMATE.CATEGORY', 'IND.PERCEN']
0.0
['CLIMATE.CATEGORY', 'RES.CUSTOMERS']
0.0
['CLIMATE.CATEGORY', 'COM.CUSTOMERS']
0.0
['CLIMATE.CATEGORY', 'IND.CUSTOMERS']
0.0
['CLIMATE.CATEGORY', 'TOTAL.CUSTOMERS']
0.0
['CLIMATE.CATEGORY', 'RES.CUST.PCT']
0.0
['CLIMATE.CATEGORY', 'COM.CUST.PCT']
0.0
['CLIMATE.CATEGORY', 'IND.CUST.PCT']
0.0
['CLIMATE.CATEGORY', 'PC.REALGSP.STATE']
0.0
['CLIMATE.CATEGORY', 'PC.REALGSP.USA']
0.0
['CLIMATE.CATEGORY', 'PC.REALGSP.REL']
0.0
['CLIMATE.CATEGORY', 'PC.REALGSP.CHANGE']
0.0
['CLIMATE.CATEGORY', 'UTIL.REALGSP']
0.0
['CLIMATE.CATEGORY', 'TOTAL.REALGSP']
0.0
['CLIMATE.CATEGORY', 'UTIL.CONTRI']
0.0
['CLIMATE.CATEGORY', 'PI.UTIL.OFUSA']
0.0
['CLIMATE.CATEGORY', 'POPULATION']
0.0
['CLIMATE.CATEGORY', 'POPPCT_URBAN']
0.0
['CLIMATE.CATEGORY', 'POPPCT_UC']
0.0
['CLIMATE.CATEGORY', 'POPDEN_URBAN']
0.0
['CLIMATE.CATEGORY', 'POPDEN_UC']
0.0
['CLIMATE.CATEGORY', 'POPDEN_RURAL']
0.005
['CLIMATE.CATEGORY', 'AREAPCT_URBAN']
0.0
['CLIMATE.CATEGORY', 'AREAPCT_UC']
0.0
['CLIMATE.CATEGORY', 'PCT_LAND']
0.0
['CLIMATE.CATEGORY', 'PCT_WATER_TOT']
0.0
['CLIMATE.CATEGORY', 'PCT_WATER_INLAND']
0.0
['CLIMATE.CATEGORY', 'OUTAGE.START']
0.0
['OUTAGE.START.DATE', 'CLIMATE.REGION']
1.0
['OUTAGE.START.DATE', 'ANOMALY.LEVEL']
1.0
['OUTAGE.START.DATE', 'CLIMATE.CATEGORY']
1.0
['OUTAGE.START.DATE', 'OUTAGE.START.TIME']
1.0
['OUTAGE.START.DATE', 'OUTAGE.RESTORATION.DATE']
1.0
['OUTAGE.START.DATE', 'OUTAGE.RESTORATION.TIME']
1.0
['OUTAGE.START.DATE', 'CAUSE.CATEGORY']
0.0
['OUTAGE.START.DATE', 'CAUSE.CATEGORY.DETAIL']
1.0
['OUTAGE.START.DATE', 'HURRICANE.NAMES']
1.0
['OUTAGE.START.DATE', 'OUTAGE.DURATION']
1.0
['OUTAGE.START.DATE', 'DEMAND.LOSS.MW']
1.0
['OUTAGE.START.DATE', 'CUSTOMERS.AFFECTED']
1.0
['OUTAGE.START.DATE', 'RES.PRICE']
1.0
['OUTAGE.START.DATE', 'COM.PRICE']
1.0
['OUTAGE.START.DATE', 'IND.PRICE']
1.0
['OUTAGE.START.DATE', 'TOTAL.PRICE']
1.0
['OUTAGE.START.DATE', 'RES.SALES']
1.0
['OUTAGE.START.DATE', 'COM.SALES']
1.0
['OUTAGE.START.DATE', 'IND.SALES']
1.0
['OUTAGE.START.DATE', 'TOTAL.SALES']
1.0
['OUTAGE.START.DATE', 'RES.PERCEN']
1.0
['OUTAGE.START.DATE', 'COM.PERCEN']
1.0
['OUTAGE.START.DATE', 'IND.PERCEN']
1.0
['OUTAGE.START.DATE', 'RES.CUSTOMERS']
0.0
['OUTAGE.START.DATE', 'COM.CUSTOMERS']
0.0
['OUTAGE.START.DATE', 'IND.CUSTOMERS']
0.0
['OUTAGE.START.DATE', 'TOTAL.CUSTOMERS']
0.0
['OUTAGE.START.DATE', 'RES.CUST.PCT']
0.0
['OUTAGE.START.DATE', 'COM.CUST.PCT']
0.0
['OUTAGE.START.DATE', 'IND.CUST.PCT']
0.0
['OUTAGE.START.DATE', 'PC.REALGSP.STATE']
0.0
['OUTAGE.START.DATE', 'PC.REALGSP.USA']
0.0
['OUTAGE.START.DATE', 'PC.REALGSP.REL']
0.0
['OUTAGE.START.DATE', 'PC.REALGSP.CHANGE']
0.0
['OUTAGE.START.DATE', 'UTIL.REALGSP']
0.0
['OUTAGE.START.DATE', 'TOTAL.REALGSP']
0.0
['OUTAGE.START.DATE', 'UTIL.CONTRI']
0.0
['OUTAGE.START.DATE', 'PI.UTIL.OFUSA']
0.0
['OUTAGE.START.DATE', 'POPULATION']
0.0
['OUTAGE.START.DATE', 'POPPCT_URBAN']
0.0
['OUTAGE.START.DATE', 'POPPCT_UC']
0.0
['OUTAGE.START.DATE', 'POPDEN_URBAN']
0.0
['OUTAGE.START.DATE', 'POPDEN_UC']
1.0
['OUTAGE.START.DATE', 'POPDEN_RURAL']
1.0
['OUTAGE.START.DATE', 'AREAPCT_URBAN']
0.0
['OUTAGE.START.DATE', 'AREAPCT_UC']
0.0
['OUTAGE.START.DATE', 'PCT_LAND']
0.0
['OUTAGE.START.DATE', 'PCT_WATER_TOT']
0.0
['OUTAGE.START.DATE', 'PCT_WATER_INLAND']
0.0
['OUTAGE.START.DATE', 'OUTAGE.START']
1.0
['OUTAGE.START.TIME', 'CLIMATE.REGION']
1.0
['OUTAGE.START.TIME', 'ANOMALY.LEVEL']
1.0
['OUTAGE.START.TIME', 'CLIMATE.CATEGORY']
1.0
['OUTAGE.START.TIME', 'OUTAGE.START.DATE']
1.0
['OUTAGE.START.TIME', 'OUTAGE.RESTORATION.DATE']
1.0
['OUTAGE.START.TIME', 'OUTAGE.RESTORATION.TIME']
1.0
['OUTAGE.START.TIME', 'CAUSE.CATEGORY']
0.0
['OUTAGE.START.TIME', 'CAUSE.CATEGORY.DETAIL']
0.97
['OUTAGE.START.TIME', 'HURRICANE.NAMES']
1.0
['OUTAGE.START.TIME', 'OUTAGE.DURATION']
1.0
['OUTAGE.START.TIME', 'DEMAND.LOSS.MW']
0.45
['OUTAGE.START.TIME', 'CUSTOMERS.AFFECTED']
1.0
['OUTAGE.START.TIME', 'RES.PRICE']
1.0
['OUTAGE.START.TIME', 'COM.PRICE']
1.0
['OUTAGE.START.TIME', 'IND.PRICE']
1.0
['OUTAGE.START.TIME', 'TOTAL.PRICE']
1.0
['OUTAGE.START.TIME', 'RES.SALES']
1.0
['OUTAGE.START.TIME', 'COM.SALES']
1.0
['OUTAGE.START.TIME', 'IND.SALES']
1.0
['OUTAGE.START.TIME', 'TOTAL.SALES']
1.0
['OUTAGE.START.TIME', 'RES.PERCEN']
1.0
['OUTAGE.START.TIME', 'COM.PERCEN']
1.0
['OUTAGE.START.TIME', 'IND.PERCEN']
1.0
['OUTAGE.START.TIME', 'RES.CUSTOMERS']
0.0
['OUTAGE.START.TIME', 'COM.CUSTOMERS']
0.0
['OUTAGE.START.TIME', 'IND.CUSTOMERS']
0.0
['OUTAGE.START.TIME', 'TOTAL.CUSTOMERS']
0.0
['OUTAGE.START.TIME', 'RES.CUST.PCT']
0.0
['OUTAGE.START.TIME', 'COM.CUST.PCT']
0.0
['OUTAGE.START.TIME', 'IND.CUST.PCT']
0.0
['OUTAGE.START.TIME', 'PC.REALGSP.STATE']
0.0
['OUTAGE.START.TIME', 'PC.REALGSP.USA']
0.0
['OUTAGE.START.TIME', 'PC.REALGSP.REL']
0.0
['OUTAGE.START.TIME', 'PC.REALGSP.CHANGE']
0.0
['OUTAGE.START.TIME', 'UTIL.REALGSP']
0.0
['OUTAGE.START.TIME', 'TOTAL.REALGSP']
0.0
['OUTAGE.START.TIME', 'UTIL.CONTRI']
0.0
['OUTAGE.START.TIME', 'PI.UTIL.OFUSA']
0.0
['OUTAGE.START.TIME', 'POPULATION']
0.0
['OUTAGE.START.TIME', 'POPPCT_URBAN']
0.0
['OUTAGE.START.TIME', 'POPPCT_UC']
0.0
['OUTAGE.START.TIME', 'POPDEN_URBAN']
0.0
['OUTAGE.START.TIME', 'POPDEN_UC']
1.0
['OUTAGE.START.TIME', 'POPDEN_RURAL']
1.0
['OUTAGE.START.TIME', 'AREAPCT_URBAN']
0.0
['OUTAGE.START.TIME', 'AREAPCT_UC']
0.0
['OUTAGE.START.TIME', 'PCT_LAND']
0.0
['OUTAGE.START.TIME', 'PCT_WATER_TOT']
0.0
['OUTAGE.START.TIME', 'PCT_WATER_INLAND']
0.0
['OUTAGE.START.TIME', 'OUTAGE.START']
1.0
['OUTAGE.RESTORATION.DATE', 'CLIMATE.REGION']
1.0
['OUTAGE.RESTORATION.DATE', 'ANOMALY.LEVEL']
1.0
['OUTAGE.RESTORATION.DATE', 'CLIMATE.CATEGORY']
1.0
['OUTAGE.RESTORATION.DATE', 'OUTAGE.START.DATE']
1.0
['OUTAGE.RESTORATION.DATE', 'OUTAGE.START.TIME']
1.0
['OUTAGE.RESTORATION.DATE', 'OUTAGE.RESTORATION.TIME']
1.0
['OUTAGE.RESTORATION.DATE', 'CAUSE.CATEGORY']
0.0
['OUTAGE.RESTORATION.DATE', 'CAUSE.CATEGORY.DETAIL']
1.0
['OUTAGE.RESTORATION.DATE', 'HURRICANE.NAMES']
1.0
['OUTAGE.RESTORATION.DATE', 'OUTAGE.DURATION']
1.0
['OUTAGE.RESTORATION.DATE', 'DEMAND.LOSS.MW']
1.0
# Out:
# 1.0

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined
